# %%
import cv2

from ultralytics import solutions


cap = cv2.VideoCapture('./video/coches.mp4')
assert cap.isOpened(), "Error reading video file"

#cap = cv2.VideoCapture(0) # if you use a camera

region_points = [(218, 264), (554, 222)]                                      # line counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # rectangle region
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]   # polygon region

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize object counter object
counter = solutions.ObjectCounter(
    show=True,  # display the output
    region=region_points,  # pass region points
    model="yolo11n.pt",  # model="yolo11n-obb.pt" for object counting with OBB model.
    # classes=[0, 2],  # count specific classes i.e. person and car with COCO pretrained model.
    # tracker="botsort.yaml",  # choose trackers i.e "bytetrack.yaml"
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = counter(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(218, 264), (554, 222)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 360x640 23.0ms
# Speed: 1971.7ms track, 23.0ms solution per image at shape (1, 3, 360, 640)
#
# 1: 360x640 14.5ms
# Speed: 63.2ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 2: 360x640 17.7ms
# Speed: 45.6ms track, 17.7ms solution per image at shape (1, 3, 360, 640)
#
# 3: 360x640 2.7ms
# Speed: 46.6ms track, 2.7ms solution per image at shape (1, 3, 360, 640)
#
# 4: 360x640 9.9ms
# Speed: 56.4ms track, 9.9ms solution per image at shape (1, 3, 360, 640)
#
# 5: 360x640 13.5ms
# Speed: 48.0ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 6: 360x640 3.7ms
# Speed: 45.2ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 7: 360x640 5.0ms
# Speed: 43.3ms track, 5.0ms solution per image at shape (1, 3, 360, 640)
#
# 8: 360x640 18.3ms
# Speed: 46.2ms track, 18.3ms solution per image at shape (1, 3, 360, 640)
#
# 9: 360x640 17.2ms
# Speed: 48.3ms track, 17.2ms solution per image at shape (1, 3, 360, 640)
#
# 10: 360x640 18.7ms
# Speed: 44.9ms track, 18.7ms solution per image at shape (1, 3, 360, 640)
#
# 11: 360x640 4.0ms
# Speed: 43.4ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 12: 360x640 4.0ms
# Speed: 44.5ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 13: 360x640 3.0ms
# Speed: 44.9ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 14: 360x640 5.6ms
# Speed: 43.5ms track, 5.6ms solution per image at shape (1, 3, 360, 640)
#
# 15: 360x640 17.1ms
# Speed: 45.8ms track, 17.1ms solution per image at shape (1, 3, 360, 640)
#
# 16: 360x640 17.6ms
# Speed: 46.4ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 17: 360x640 3.4ms
# Speed: 46.1ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 18: 360x640 4.7ms
# Speed: 43.6ms track, 4.7ms solution per image at shape (1, 3, 360, 640)
#
# 19: 360x640 2.7ms
# Speed: 47.1ms track, 2.7ms solution per image at shape (1, 3, 360, 640)
#
# 20: 360x640 2.8ms
# Speed: 44.0ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 21: 360x640 3.1ms
# Speed: 44.4ms track, 3.1ms solution per image at shape (1, 3, 360, 640)
#
# 22: 360x640 3.3ms
# Speed: 43.6ms track, 3.3ms solution per image at shape (1, 3, 360, 640)
#
# 23: 360x640 16.9ms
# Speed: 48.5ms track, 16.9ms solution per image at shape (1, 3, 360, 640)
#
# 24: 360x640 17.8ms
# Speed: 46.4ms track, 17.8ms solution per image at shape (1, 3, 360, 640)
#
# 25: 360x640 16.7ms
# Speed: 48.1ms track, 16.7ms solution per image at shape (1, 3, 360, 640)
#
# 26: 360x640 4.0ms
# Speed: 45.7ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 27: 360x640 3.3ms
# Speed: 44.2ms track, 3.3ms solution per image at shape (1, 3, 360, 640)
#
# 28: 360x640 16.5ms
# Speed: 45.6ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 29: 360x640 5.0ms
# Speed: 45.4ms track, 5.0ms solution per image at shape (1, 3, 360, 640)
#
# 30: 360x640 2.8ms
# Speed: 44.4ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 31: 360x640 4.0ms
# Speed: 45.2ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 32: 360x640 16.4ms
# Speed: 46.0ms track, 16.4ms solution per image at shape (1, 3, 360, 640)
#
# 33: 360x640 2.6ms
# Speed: 45.4ms track, 2.6ms solution per image at shape (1, 3, 360, 640)
#
# 34: 360x640 3.2ms
# Speed: 45.2ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 35: 360x640 2.6ms
# Speed: 45.6ms track, 2.6ms solution per image at shape (1, 3, 360, 640)
#
# 36: 360x640 18.1ms
# Speed: 46.4ms track, 18.1ms solution per image at shape (1, 3, 360, 640)
#
# 37: 360x640 14.7ms
# Speed: 49.1ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 38: 360x640 6.6ms
# Speed: 42.2ms track, 6.6ms solution per image at shape (1, 3, 360, 640)
#
# 39: 360x640 6.7ms
# Speed: 40.5ms track, 6.7ms solution per image at shape (1, 3, 360, 640)
#
# 40: 360x640 16.2ms
# Speed: 64.1ms track, 16.2ms solution per image at shape (1, 3, 360, 640)
#
# 41: 360x640 10.1ms
# Speed: 42.4ms track, 10.1ms solution per image at shape (1, 3, 360, 640)
#
# 42: 360x640 19.3ms
# Speed: 42.0ms track, 19.3ms solution per image at shape (1, 3, 360, 640)
#
# 43: 360x640 7.3ms
# Speed: 41.2ms track, 7.3ms solution per image at shape (1, 3, 360, 640)
#
# 44: 360x640 2.5ms
# Speed: 45.7ms track, 2.5ms solution per image at shape (1, 3, 360, 640)
#
# 45: 360x640 7.0ms
# Speed: 40.7ms track, 7.0ms solution per image at shape (1, 3, 360, 640)
#
# 46: 360x640 5.3ms
# Speed: 44.1ms track, 5.3ms solution per image at shape (1, 3, 360, 640)
#
# 47: 360x640 6.0ms
# Speed: 42.0ms track, 6.0ms solution per image at shape (1, 3, 360, 640)
#
# 48: 360x640 5.3ms
# Speed: 42.7ms track, 5.3ms solution per image at shape (1, 3, 360, 640)
#
# 49: 360x640 6.4ms
# Speed: 40.2ms track, 6.4ms solution per image at shape (1, 3, 360, 640)
#
# 50: 360x640 9.1ms
# Speed: 40.3ms track, 9.1ms solution per image at shape (1, 3, 360, 640)
#
# 51: 360x640 5.9ms
# Speed: 41.0ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 52: 360x640 5.2ms
# Speed: 44.6ms track, 5.2ms solution per image at shape (1, 3, 360, 640)
#
# 53: 360x640 2.7ms
# Speed: 44.8ms track, 2.7ms solution per image at shape (1, 3, 360, 640)
#
# 54: 360x640 2.4ms
# Speed: 46.6ms track, 2.4ms solution per image at shape (1, 3, 360, 640)
#
# 55: 360x640 13.9ms
# Speed: 49.9ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 56: 360x640 3.4ms
# Speed: 44.5ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 57: 360x640 17.7ms
# Speed: 45.2ms track, 17.7ms solution per image at shape (1, 3, 360, 640)
#
# 58: 360x640 3.8ms
# Speed: 44.9ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 59: 360x640 2.9ms
# Speed: 53.1ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 60: 360x640 9.2ms
# Speed: 60.2ms track, 9.2ms solution per image at shape (1, 3, 360, 640)
#
# 61: 360x640 12.4ms
# Speed: 55.1ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 62: 360x640 10.0ms
# Speed: 54.9ms track, 10.0ms solution per image at shape (1, 3, 360, 640)
#
# 63: 360x640 2.6ms
# Speed: 57.0ms track, 2.6ms solution per image at shape (1, 3, 360, 640)
#
# 64: 360x640 2.4ms
# Speed: 56.6ms track, 2.4ms solution per image at shape (1, 3, 360, 640)
#
# 65: 360x640 10.5ms
# Speed: 49.1ms track, 10.5ms solution per image at shape (1, 3, 360, 640)
#
# 66: 360x640 9.6ms
# Speed: 50.0ms track, 9.6ms solution per image at shape (1, 3, 360, 640)
#
# 67: 360x640 6.4ms
# Speed: 51.8ms track, 6.4ms solution per image at shape (1, 3, 360, 640)
#
# 68: 360x640 12.7ms
# Speed: 46.9ms track, 12.7ms solution per image at shape (1, 3, 360, 640)
#
# 69: 360x640 10.1ms
# Speed: 48.5ms track, 10.1ms solution per image at shape (1, 3, 360, 640)
#
# 70: 360x640 11.3ms
# Speed: 48.2ms track, 11.3ms solution per image at shape (1, 3, 360, 640)
#
# 71: 360x640 7.6ms
# Speed: 50.6ms track, 7.6ms solution per image at shape (1, 3, 360, 640)
#
# 72: 360x640 7.7ms
# Speed: 51.4ms track, 7.7ms solution per image at shape (1, 3, 360, 640)
#
# 73: 360x640 11.2ms
# Speed: 47.2ms track, 11.2ms solution per image at shape (1, 3, 360, 640)
#
# 74: 360x640 11.2ms
# Speed: 47.8ms track, 11.2ms solution per image at shape (1, 3, 360, 640)
#
# 75: 360x640 4.7ms
# Speed: 53.3ms track, 4.7ms solution per image at shape (1, 3, 360, 640)
#
# 76: 360x640 7.1ms
# Speed: 51.1ms track, 7.1ms solution per image at shape (1, 3, 360, 640)
#
# 77: 360x640 11.3ms
# Speed: 46.9ms track, 11.3ms solution per image at shape (1, 3, 360, 640)
#
# 78: 360x640 7.5ms
# Speed: 52.4ms track, 7.5ms solution per image at shape (1, 3, 360, 640)
#
# 79: 360x640 9.8ms
# Speed: 50.6ms track, 9.8ms solution per image at shape (1, 3, 360, 640)
#
# 80: 360x640 10.9ms
# Speed: 48.1ms track, 10.9ms solution per image at shape (1, 3, 360, 640)
#
# 81: 360x640 12.9ms
# Speed: 46.6ms track, 12.9ms solution per image at shape (1, 3, 360, 640)
#
# 82: 360x640 8.3ms
# Speed: 50.3ms track, 8.3ms solution per image at shape (1, 3, 360, 640)
#
# 83: 360x640 11.4ms
# Speed: 48.7ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 84: 360x640 14.4ms
# Speed: 44.9ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 85: 360x640 9.8ms
# Speed: 45.3ms track, 9.8ms solution per image at shape (1, 3, 360, 640)
#
# 86: 360x640 2.3ms
# Speed: 46.9ms track, 2.3ms solution per image at shape (1, 3, 360, 640)
#
# 87: 360x640 9.4ms
# Speed: 51.0ms track, 9.4ms solution per image at shape (1, 3, 360, 640)
#
# 88: 360x640 15.4ms
# Speed: 52.4ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 89: 360x640 5.3ms
# Speed: 62.8ms track, 5.3ms solution per image at shape (1, 3, 360, 640)
#
# 90: 360x640 15.2ms
# Speed: 48.9ms track, 15.2ms solution per image at shape (1, 3, 360, 640)
#
# 91: 360x640 13.6ms
# Speed: 66.6ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 92: 360x640 4.2ms
# Speed: 61.7ms track, 4.2ms solution per image at shape (1, 3, 360, 640)
#
# 93: 360x640 14.1ms
# Speed: 65.5ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 94: 360x640 15.4ms
# Speed: 67.9ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 95: 360x640 12.8ms
# Speed: 67.9ms track, 12.8ms solution per image at shape (1, 3, 360, 640)
#
# 96: 360x640 10.1ms
# Speed: 69.6ms track, 10.1ms solution per image at shape (1, 3, 360, 640)
#
# 97: 360x640 13.1ms
# Speed: 69.0ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 98: 360x640 5.5ms
# Speed: 59.0ms track, 5.5ms solution per image at shape (1, 3, 360, 640)
#
# 99: 360x640 13.9ms
# Speed: 67.6ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 100: 360x640 3.8ms
# Speed: 60.8ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 101: 360x640 17.6ms
# Speed: 64.2ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 102: 360x640 3.6ms
# Speed: 75.7ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 103: 360x640 12.4ms
# Speed: 69.2ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 104: 360x640 2.2ms
# Speed: 62.3ms track, 2.2ms solution per image at shape (1, 3, 360, 640)
#
# 105: 360x640 9.5ms
# Speed: 54.5ms track, 9.5ms solution per image at shape (1, 3, 360, 640)
#
# 106: 360x640 10.4ms
# Speed: 54.3ms track, 10.4ms solution per image at shape (1, 3, 360, 640)
#
# 107: 360x640 3.2ms
# Speed: 62.4ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 108: 360x640 14.2ms
# Speed: 67.5ms track, 14.2ms solution per image at shape (1, 3, 360, 640)
#
# 109: 360x640 3.7ms
# Speed: 60.5ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 110: 360x640 16.7ms
# Speed: 63.9ms track, 16.7ms solution per image at shape (1, 3, 360, 640)
#
# 111: 360x640 7.8ms
# Speed: 57.3ms track, 7.8ms solution per image at shape (1, 3, 360, 640)
#
# 112: 360x640 13.9ms
# Speed: 65.3ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 113: 360x640 6.8ms
# Speed: 57.6ms track, 6.8ms solution per image at shape (1, 3, 360, 640)
#
# 114: 360x640 17.6ms
# Speed: 64.4ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 115: 360x640 3.7ms
# Speed: 59.6ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 116: 360x640 14.6ms
# Speed: 66.7ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 117: 360x640 3.0ms
# Speed: 61.9ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 118: 360x640 5.6ms
# Speed: 58.7ms track, 5.6ms solution per image at shape (1, 3, 360, 640)
#
# 119: 360x640 4.6ms
# Speed: 61.9ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 120: 360x640 8.3ms
# Speed: 70.6ms track, 8.3ms solution per image at shape (1, 3, 360, 640)
#
# 121: 360x640 8.1ms
# Speed: 72.5ms track, 8.1ms solution per image at shape (1, 3, 360, 640)
#
# 122: 360x640 14.4ms
# Speed: 67.2ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 123: 360x640 5.9ms
# Speed: 58.4ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 124: 360x640 13.1ms
# Speed: 51.3ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 125: 360x640 3.7ms
# Speed: 62.2ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 126: 360x640 14.1ms
# Speed: 67.7ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 127: 360x640 6.2ms
# Speed: 73.1ms track, 6.2ms solution per image at shape (1, 3, 360, 640)
#
# 128: 360x640 2.7ms
# Speed: 63.5ms track, 2.7ms solution per image at shape (1, 3, 360, 640)
#
# 129: 360x640 15.3ms
# Speed: 64.5ms track, 15.3ms solution per image at shape (1, 3, 360, 640)
#
# 130: 360x640 6.6ms
# Speed: 58.4ms track, 6.6ms solution per image at shape (1, 3, 360, 640)
#
# 131: 360x640 15.9ms
# Speed: 65.4ms track, 15.9ms solution per image at shape (1, 3, 360, 640)
#
# 132: 360x640 11.9ms
# Speed: 69.0ms track, 11.9ms solution per image at shape (1, 3, 360, 640)
#
# 133: 360x640 4.2ms
# Speed: 59.5ms track, 4.2ms solution per image at shape (1, 3, 360, 640)
#
# 134: 360x640 4.1ms
# Speed: 64.1ms track, 4.1ms solution per image at shape (1, 3, 360, 640)
#
# 135: 360x640 9.2ms
# Speed: 51.3ms track, 9.2ms solution per image at shape (1, 3, 360, 640)
#
# 136: 360x640 12.5ms
# Speed: 52.5ms track, 12.5ms solution per image at shape (1, 3, 360, 640)
#
# 137: 360x640 3.6ms
# Speed: 61.3ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 138: 360x640 13.8ms
# Speed: 50.8ms track, 13.8ms solution per image at shape (1, 3, 360, 640)
#
# 139: 360x640 16.0ms
# Speed: 49.8ms track, 16.0ms solution per image at shape (1, 3, 360, 640)
#
# 140: 360x640 9.0ms
# Speed: 54.5ms track, 9.0ms solution per image at shape (1, 3, 360, 640)
#
# 141: 360x640 8.6ms
# Speed: 72.6ms track, 8.6ms solution per image at shape (1, 3, 360, 640)
#
# 142: 360x640 15.3ms
# Speed: 66.0ms track, 15.3ms solution per image at shape (1, 3, 360, 640)
#
# 143: 360x640 2.9ms
# Speed: 62.4ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 144: 360x640 2.4ms
# Speed: 62.7ms track, 2.4ms solution per image at shape (1, 3, 360, 640)
#
# 145: 360x640 9.5ms
# Speed: 70.7ms track, 9.5ms solution per image at shape (1, 3, 360, 640)
#
# 146: 360x640 14.1ms
# Speed: 66.7ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 147: 360x640 8.1ms
# Speed: 56.3ms track, 8.1ms solution per image at shape (1, 3, 360, 640)
#
# 148: 360x640 18.1ms
# Speed: 63.3ms track, 18.1ms solution per image at shape (1, 3, 360, 640)
#
# 149: 360x640 16.4ms
# Speed: 64.5ms track, 16.4ms solution per image at shape (1, 3, 360, 640)
#
# 150: 360x640 7.0ms
# Speed: 58.0ms track, 7.0ms solution per image at shape (1, 3, 360, 640)
#
# 151: 360x640 14.5ms
# Speed: 66.3ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 152: 360x640 5.9ms
# Speed: 58.7ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 153: 360x640 3.7ms
# Speed: 62.3ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 154: 360x640 14.1ms
# Speed: 65.2ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 155: 360x640 15.9ms
# Speed: 65.7ms track, 15.9ms solution per image at shape (1, 3, 360, 640)
#
# 156: 360x640 4.6ms
# Speed: 60.4ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 157: 360x640 12.8ms
# Speed: 68.5ms track, 12.8ms solution per image at shape (1, 3, 360, 640)
#
# 158: 360x640 5.3ms
# Speed: 61.5ms track, 5.3ms solution per image at shape (1, 3, 360, 640)
#
# 159: 360x640 11.9ms
# Speed: 70.5ms track, 11.9ms solution per image at shape (1, 3, 360, 640)
#
# 160: 360x640 15.0ms
# Speed: 78.7ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 161: 360x640 16.7ms
# Speed: 64.4ms track, 16.7ms solution per image at shape (1, 3, 360, 640)
#
# 162: 360x640 14.7ms
# Speed: 65.7ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 163: 360x640 7.5ms
# Speed: 58.6ms track, 7.5ms solution per image at shape (1, 3, 360, 640)
#
# 164: 360x640 13.6ms
# Speed: 67.3ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 165: 360x640 7.8ms
# Speed: 56.9ms track, 7.8ms solution per image at shape (1, 3, 360, 640)
#
# 166: 360x640 5.9ms
# Speed: 59.0ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 167: 360x640 8.9ms
# Speed: 70.1ms track, 8.9ms solution per image at shape (1, 3, 360, 640)
#
# 168: 360x640 11.7ms
# Speed: 69.5ms track, 11.7ms solution per image at shape (1, 3, 360, 640)
#
# 169: 360x640 3.7ms
# Speed: 62.2ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 170: 360x640 6.0ms
# Speed: 58.4ms track, 6.0ms solution per image at shape (1, 3, 360, 640)
#
# 171: 360x640 3.2ms
# Speed: 61.2ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 172: 360x640 3.7ms
# Speed: 66.7ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 173: 360x640 7.8ms
# Speed: 67.7ms track, 7.8ms solution per image at shape (1, 3, 360, 640)
#
# 174: 360x640 13.0ms
# Speed: 68.7ms track, 13.0ms solution per image at shape (1, 3, 360, 640)
#
# 175: 360x640 15.5ms
# Speed: 66.0ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 176: 360x640 5.5ms
# Speed: 58.7ms track, 5.5ms solution per image at shape (1, 3, 360, 640)
#
# 177: 360x640 5.5ms
# Speed: 59.0ms track, 5.5ms solution per image at shape (1, 3, 360, 640)
#
# 178: 360x640 9.1ms
# Speed: 54.5ms track, 9.1ms solution per image at shape (1, 3, 360, 640)
#
# 179: 360x640 8.5ms
# Speed: 56.5ms track, 8.5ms solution per image at shape (1, 3, 360, 640)
#
# 180: 360x640 9.6ms
# Speed: 105.7ms track, 9.6ms solution per image at shape (1, 3, 360, 640)
#
# 181: 360x640 17.1ms
# Speed: 62.8ms track, 17.1ms solution per image at shape (1, 3, 360, 640)
#
# 182: 360x640 3.6ms
# Speed: 61.1ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 183: 360x640 9.1ms
# Speed: 70.5ms track, 9.1ms solution per image at shape (1, 3, 360, 640)
#
# 184: 360x640 6.0ms
# Speed: 56.7ms track, 6.0ms solution per image at shape (1, 3, 360, 640)
#
# 185: 360x640 8.9ms
# Speed: 58.4ms track, 8.9ms solution per image at shape (1, 3, 360, 640)
#
# 186: 360x640 15.5ms
# Speed: 65.1ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 187: 360x640 3.0ms
# Speed: 61.1ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 188: 360x640 16.2ms
# Speed: 64.9ms track, 16.2ms solution per image at shape (1, 3, 360, 640)
#
# 189: 360x640 14.5ms
# Speed: 67.9ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 190: 360x640 4.8ms
# Speed: 60.0ms track, 4.8ms solution per image at shape (1, 3, 360, 640)
#
# 191: 360x640 17.3ms
# Speed: 63.4ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 192: 360x640 11.7ms
# Speed: 68.8ms track, 11.7ms solution per image at shape (1, 3, 360, 640)
#
# 193: 360x640 6.9ms
# Speed: 58.3ms track, 6.9ms solution per image at shape (1, 3, 360, 640)
#
# 194: 360x640 16.3ms
# Speed: 64.6ms track, 16.3ms solution per image at shape (1, 3, 360, 640)
#
# 195: 360x640 3.1ms
# Speed: 63.2ms track, 3.1ms solution per image at shape (1, 3, 360, 640)
#
# 196: 360x640 10.3ms
# Speed: 69.5ms track, 10.3ms solution per image at shape (1, 3, 360, 640)
#
# 197: 360x640 4.1ms
# Speed: 63.4ms track, 4.1ms solution per image at shape (1, 3, 360, 640)
#
# 198: 360x640 10.6ms
# Speed: 67.5ms track, 10.6ms solution per image at shape (1, 3, 360, 640)
#
# 199: 360x640 14.2ms
# Speed: 67.1ms track, 14.2ms solution per image at shape (1, 3, 360, 640)
#
# 200: 360x640 15.1ms
# Speed: 65.7ms track, 15.1ms solution per image at shape (1, 3, 360, 640)
#
# 201: 360x640 11.1ms
# Speed: 70.3ms track, 11.1ms solution per image at shape (1, 3, 360, 640)
#
# 202: 360x640 14.8ms
# Speed: 67.2ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 203: 360x640 5.7ms
# Speed: 58.6ms track, 5.7ms solution per image at shape (1, 3, 360, 640)
#
# 204: 360x640 6.5ms
# Speed: 58.5ms track, 6.5ms solution per image at shape (1, 3, 360, 640)
#
# 205: 360x640 7.0ms
# Speed: 57.5ms track, 7.0ms solution per image at shape (1, 3, 360, 640)
#
# 206: 360x640 15.9ms
# Speed: 66.8ms track, 15.9ms solution per image at shape (1, 3, 360, 640)
#
# 207: 360x640 13.9ms
# Speed: 66.5ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 208: 360x640 12.8ms
# Speed: 52.2ms track, 12.8ms solution per image at shape (1, 3, 360, 640)
#
# 209: 360x640 17.3ms
# Speed: 64.5ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 210: 360x640 13.3ms
# Speed: 66.7ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 211: 360x640 8.6ms
# Speed: 56.5ms track, 8.6ms solution per image at shape (1, 3, 360, 640)
#
# 212: 360x640 7.6ms
# Speed: 73.9ms track, 7.6ms solution per image at shape (1, 3, 360, 640)
#
# 213: 360x640 15.6ms
# Speed: 66.3ms track, 15.6ms solution per image at shape (1, 3, 360, 640)
#
# 214: 360x640 7.9ms
# Speed: 56.2ms track, 7.9ms solution per image at shape (1, 3, 360, 640)
#
# 215: 360x640 15.7ms
# Speed: 67.0ms track, 15.7ms solution per image at shape (1, 3, 360, 640)
#
# 216: 360x640 13.1ms
# Speed: 68.5ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 217: 360x640 11.8ms
# Speed: 65.8ms track, 11.8ms solution per image at shape (1, 3, 360, 640)
#
# 218: 360x640 6.6ms
# Speed: 57.4ms track, 6.6ms solution per image at shape (1, 3, 360, 640)
#
# 219: 360x640 17.9ms
# Speed: 63.0ms track, 17.9ms solution per image at shape (1, 3, 360, 640)
#
# 220: 360x640 6.0ms
# Speed: 58.8ms track, 6.0ms solution per image at shape (1, 3, 360, 640)
#
# 221: 360x640 5.4ms
# Speed: 60.0ms track, 5.4ms solution per image at shape (1, 3, 360, 640)
#
# 222: 360x640 15.9ms
# Speed: 65.2ms track, 15.9ms solution per image at shape (1, 3, 360, 640)
#
# 223: 360x640 2.8ms
# Speed: 62.2ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 224: 360x640 9.0ms
# Speed: 54.6ms track, 9.0ms solution per image at shape (1, 3, 360, 640)
#
# 225: 360x640 3.0ms
# Speed: 62.6ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 226: 360x640 7.1ms
# Speed: 56.5ms track, 7.1ms solution per image at shape (1, 3, 360, 640)
#
# 227: 360x640 11.0ms
# Speed: 53.8ms track, 11.0ms solution per image at shape (1, 3, 360, 640)
#
# 228: 360x640 16.6ms
# Speed: 65.1ms track, 16.6ms solution per image at shape (1, 3, 360, 640)
#
# 229: 360x640 3.6ms
# Speed: 60.3ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 230: 360x640 4.3ms
# Speed: 63.1ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 231: 360x640 5.7ms
# Speed: 57.1ms track, 5.7ms solution per image at shape (1, 3, 360, 640)
#
# 232: 360x640 7.8ms
# Speed: 56.8ms track, 7.8ms solution per image at shape (1, 3, 360, 640)
#
# 233: 360x640 14.7ms
# Speed: 83.7ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 234: 360x640 3.8ms
# Speed: 77.1ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 235: 360x640 12.4ms
# Speed: 69.1ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 236: 360x640 16.1ms
# Speed: 66.3ms track, 16.1ms solution per image at shape (1, 3, 360, 640)
#
# 237: 360x640 13.6ms
# Speed: 68.7ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 238: 360x640 13.3ms
# Speed: 65.8ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 239: 360x640 13.0ms
# Speed: 69.0ms track, 13.0ms solution per image at shape (1, 3, 360, 640)
#
# 240: 360x640 8.5ms
# Speed: 71.8ms track, 8.5ms solution per image at shape (1, 3, 360, 640)
#
# 241: 360x640 3.8ms
# Speed: 76.8ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 242: 360x640 8.7ms
# Speed: 72.5ms track, 8.7ms solution per image at shape (1, 3, 360, 640)
#
# 243: 360x640 13.1ms
# Speed: 68.0ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 244: 360x640 12.8ms
# Speed: 69.7ms track, 12.8ms solution per image at shape (1, 3, 360, 640)
#
# 245: 360x640 2.9ms
# Speed: 61.1ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 246: 360x640 12.4ms
# Speed: 70.6ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 247: 360x640 9.5ms
# Speed: 70.3ms track, 9.5ms solution per image at shape (1, 3, 360, 640)
#
# 248: 360x640 5.9ms
# Speed: 61.3ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 249: 360x640 17.3ms
# Speed: 62.2ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 250: 360x640 12.9ms
# Speed: 68.6ms track, 12.9ms solution per image at shape (1, 3, 360, 640)
#
# 251: 360x640 3.3ms
# Speed: 61.8ms track, 3.3ms solution per image at shape (1, 3, 360, 640)
#
# 252: 360x640 14.3ms
# Speed: 67.7ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 253: 360x640 13.7ms
# Speed: 66.0ms track, 13.7ms solution per image at shape (1, 3, 360, 640)
#
# 254: 360x640 4.0ms
# Speed: 61.2ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 255: 360x640 14.8ms
# Speed: 66.7ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 256: 360x640 8.1ms
# Speed: 56.6ms track, 8.1ms solution per image at shape (1, 3, 360, 640)
#
# 257: 360x640 3.8ms
# Speed: 60.4ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 258: 360x640 5.2ms
# Speed: 59.1ms track, 5.2ms solution per image at shape (1, 3, 360, 640)
#
# 259: 360x640 8.7ms
# Speed: 56.8ms track, 8.7ms solution per image at shape (1, 3, 360, 640)
#
# 260: 360x640 16.6ms
# Speed: 64.4ms track, 16.6ms solution per image at shape (1, 3, 360, 640)
#
# 261: 360x640 16.6ms
# Speed: 65.7ms track, 16.6ms solution per image at shape (1, 3, 360, 640)
#
# 262: 360x640 2.8ms
# Speed: 63.2ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 263: 360x640 12.5ms
# Speed: 67.8ms track, 12.5ms solution per image at shape (1, 3, 360, 640)
#
# 264: 360x640 12.2ms
# Speed: 70.5ms track, 12.2ms solution per image at shape (1, 3, 360, 640)
#
# 265: 360x640 10.2ms
# Speed: 69.3ms track, 10.2ms solution per image at shape (1, 3, 360, 640)
#
# 266: 360x640 9.7ms
# Speed: 70.6ms track, 9.7ms solution per image at shape (1, 3, 360, 640)
#
# 267: 360x640 15.5ms
# Speed: 66.7ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 268: 360x640 7.9ms
# Speed: 56.6ms track, 7.9ms solution per image at shape (1, 3, 360, 640)
#
# 269: 360x640 10.0ms
# Speed: 53.4ms track, 10.0ms solution per image at shape (1, 3, 360, 640)
#
# 270: 360x640 5.1ms
# Speed: 59.6ms track, 5.1ms solution per image at shape (1, 3, 360, 640)
#
# 271: 360x640 3.4ms
# Speed: 78.1ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 272: 360x640 3.0ms
# Speed: 80.9ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 273: 360x640 7.7ms
# Speed: 69.7ms track, 7.7ms solution per image at shape (1, 3, 360, 640)
#
# 274: 360x640 5.6ms
# Speed: 61.3ms track, 5.6ms solution per image at shape (1, 3, 360, 640)
#
# 275: 360x640 15.6ms
# Speed: 64.3ms track, 15.6ms solution per image at shape (1, 3, 360, 640)
#
# 276: 360x640 13.5ms
# Speed: 68.3ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 277: 360x640 14.5ms
# Speed: 67.1ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 278: 360x640 2.6ms
# Speed: 60.2ms track, 2.6ms solution per image at shape (1, 3, 360, 640)
#
# 279: 360x640 13.1ms
# Speed: 68.1ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 280: 360x640 12.1ms
# Speed: 69.8ms track, 12.1ms solution per image at shape (1, 3, 360, 640)
#
# 281: 360x640 14.5ms
# Speed: 66.1ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 282: 360x640 2.8ms
# Speed: 62.2ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 283: 360x640 9.0ms
# Speed: 54.4ms track, 9.0ms solution per image at shape (1, 3, 360, 640)
#
# 284: 360x640 7.5ms
# Speed: 57.1ms track, 7.5ms solution per image at shape (1, 3, 360, 640)
#
# 285: 360x640 4.2ms
# Speed: 61.1ms track, 4.2ms solution per image at shape (1, 3, 360, 640)
#
# 286: 360x640 6.0ms
# Speed: 58.8ms track, 6.0ms solution per image at shape (1, 3, 360, 640)
#
# 287: 360x640 17.0ms
# Speed: 64.0ms track, 17.0ms solution per image at shape (1, 3, 360, 640)
#
# 288: 360x640 17.6ms
# Speed: 63.5ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 289: 360x640 6.3ms
# Speed: 59.4ms track, 6.3ms solution per image at shape (1, 3, 360, 640)
#
# 290: 360x640 15.9ms
# Speed: 65.9ms track, 15.9ms solution per image at shape (1, 3, 360, 640)
#
# 291: 360x640 9.4ms
# Speed: 53.9ms track, 9.4ms solution per image at shape (1, 3, 360, 640)
#
# 292: 360x640 5.4ms
# Speed: 59.2ms track, 5.4ms solution per image at shape (1, 3, 360, 640)
#
# 293: 360x640 15.6ms
# Speed: 66.8ms track, 15.6ms solution per image at shape (1, 3, 360, 640)
#
# 294: 360x640 8.5ms
# Speed: 68.9ms track, 8.5ms solution per image at shape (1, 3, 360, 640)
#
# 295: 360x640 9.7ms
# Speed: 64.5ms track, 9.7ms solution per image at shape (1, 3, 360, 640)
#
# 296: 360x640 10.7ms
# Speed: 64.1ms track, 10.7ms solution per image at shape (1, 3, 360, 640)
#
# 297: 360x640 2.9ms
# Speed: 61.3ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 298: 360x640 6.6ms
# Speed: 58.6ms track, 6.6ms solution per image at shape (1, 3, 360, 640)
#
# 299: 360x640 15.8ms
# Speed: 64.6ms track, 15.8ms solution per image at shape (1, 3, 360, 640)
#
# 300: 360x640 13.3ms
# Speed: 68.7ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 301: 360x640 2.9ms
# Speed: 63.4ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 302: 360x640 2.6ms
# Speed: 59.4ms track, 2.6ms solution per image at shape (1, 3, 360, 640)
#
# 303: 360x640 13.9ms
# Speed: 67.3ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 304: 360x640 7.9ms
# Speed: 76.0ms track, 7.9ms solution per image at shape (1, 3, 360, 640)
#
# 305: 360x640 4.2ms
# Speed: 75.4ms track, 4.2ms solution per image at shape (1, 3, 360, 640)
#
# 306: 360x640 5.5ms
# Speed: 67.1ms track, 5.5ms solution per image at shape (1, 3, 360, 640)
#
# 307: 360x640 8.8ms
# Speed: 49.2ms track, 8.8ms solution per image at shape (1, 3, 360, 640)
#
# 308: 360x640 11.7ms
# Speed: 54.2ms track, 11.7ms solution per image at shape (1, 3, 360, 640)
#
# 309: 360x640 6.2ms
# Speed: 56.1ms track, 6.2ms solution per image at shape (1, 3, 360, 640)
#
# 310: 360x640 8.6ms
# Speed: 54.6ms track, 8.6ms solution per image at shape (1, 3, 360, 640)
#
# 311: 360x640 9.3ms
# Speed: 56.8ms track, 9.3ms solution per image at shape (1, 3, 360, 640)
#
# 312: 360x640 7.8ms
# Speed: 57.0ms track, 7.8ms solution per image at shape (1, 3, 360, 640)
#
# 313: 360x640 10.7ms
# Speed: 53.7ms track, 10.7ms solution per image at shape (1, 3, 360, 640)
#
# 314: 360x640 5.2ms
# Speed: 59.6ms track, 5.2ms solution per image at shape (1, 3, 360, 640)
#
# 315: 360x640 18.1ms
# Speed: 63.7ms track, 18.1ms solution per image at shape (1, 3, 360, 640)
#
# 316: 360x640 3.2ms
# Speed: 61.0ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 317: 360x640 7.1ms
# Speed: 55.1ms track, 7.1ms solution per image at shape (1, 3, 360, 640)
#
# 318: 360x640 6.9ms
# Speed: 60.2ms track, 6.9ms solution per image at shape (1, 3, 360, 640)
#
# 319: 360x640 8.3ms
# Speed: 56.2ms track, 8.3ms solution per image at shape (1, 3, 360, 640)
#
# 320: 360x640 4.5ms
# Speed: 60.6ms track, 4.5ms solution per image at shape (1, 3, 360, 640)
#
# 321: 360x640 8.3ms
# Speed: 57.0ms track, 8.3ms solution per image at shape (1, 3, 360, 640)
#
# 322: 360x640 8.8ms
# Speed: 71.1ms track, 8.8ms solution per image at shape (1, 3, 360, 640)
#
# 323: 360x640 10.4ms
# Speed: 71.4ms track, 10.4ms solution per image at shape (1, 3, 360, 640)
#
# 324: 360x640 15.3ms
# Speed: 65.3ms track, 15.3ms solution per image at shape (1, 3, 360, 640)
#
# 325: 360x640 17.6ms
# Speed: 63.7ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 326: 360x640 13.5ms
# Speed: 67.2ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 327: 360x640 7.8ms
# Speed: 59.2ms track, 7.8ms solution per image at shape (1, 3, 360, 640)
#
# 328: 360x640 18.0ms
# Speed: 62.6ms track, 18.0ms solution per image at shape (1, 3, 360, 640)
#
# 329: 360x640 17.6ms
# Speed: 63.3ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 330: 360x640 17.2ms
# Speed: 62.1ms track, 17.2ms solution per image at shape (1, 3, 360, 640)
#
# 331: 360x640 15.0ms
# Speed: 84.5ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 332: 360x640 13.1ms
# Speed: 83.9ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 333: 360x640 3.3ms
# Speed: 60.7ms track, 3.3ms solution per image at shape (1, 3, 360, 640)
#
# 334: 360x640 3.1ms
# Speed: 62.0ms track, 3.1ms solution per image at shape (1, 3, 360, 640)
#
# 335: 360x640 14.4ms
# Speed: 67.4ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 336: 360x640 10.2ms
# Speed: 55.7ms track, 10.2ms solution per image at shape (1, 3, 360, 640)
#
# 337: 360x640 28.2ms
# Speed: 52.1ms track, 28.2ms solution per image at shape (1, 3, 360, 640)
#
# 338: 360x640 16.1ms
# Speed: 65.3ms track, 16.1ms solution per image at shape (1, 3, 360, 640)
#
# 339: 360x640 10.2ms
# Speed: 71.6ms track, 10.2ms solution per image at shape (1, 3, 360, 640)
#
# 340: 360x640 13.2ms
# Speed: 68.2ms track, 13.2ms solution per image at shape (1, 3, 360, 640)
#
# 341: 360x640 10.8ms
# Speed: 69.5ms track, 10.8ms solution per image at shape (1, 3, 360, 640)
#
# 342: 360x640 2.9ms
# Speed: 63.8ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 343: 360x640 13.6ms
# Speed: 66.7ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 344: 360x640 13.9ms
# Speed: 67.1ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 345: 360x640 13.6ms
# Speed: 67.7ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 346: 360x640 12.9ms
# Speed: 69.5ms track, 12.9ms solution per image at shape (1, 3, 360, 640)
#
# 347: 360x640 13.9ms
# Speed: 65.9ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 348: 360x640 4.3ms
# Speed: 61.1ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 349: 360x640 10.1ms
# Speed: 70.6ms track, 10.1ms solution per image at shape (1, 3, 360, 640)
#
# 350: 360x640 6.4ms
# Speed: 57.8ms track, 6.4ms solution per image at shape (1, 3, 360, 640)
#
# 351: 360x640 13.3ms
# Speed: 67.8ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 352: 360x640 11.3ms
# Speed: 69.2ms track, 11.3ms solution per image at shape (1, 3, 360, 640)
#
# 353: 360x640 13.9ms
# Speed: 67.3ms track, 13.9ms solution per image at shape (1, 3, 360, 640)
#
# 354: 360x640 5.7ms
# Speed: 60.0ms track, 5.7ms solution per image at shape (1, 3, 360, 640)
#
# 355: 360x640 5.6ms
# Speed: 57.0ms track, 5.6ms solution per image at shape (1, 3, 360, 640)
#
# 356: 360x640 12.6ms
# Speed: 69.4ms track, 12.6ms solution per image at shape (1, 3, 360, 640)
#
# 357: 360x640 9.9ms
# Speed: 70.8ms track, 9.9ms solution per image at shape (1, 3, 360, 640)
#
# 358: 360x640 15.9ms
# Speed: 66.3ms track, 15.9ms solution per image at shape (1, 3, 360, 640)
#
# 359: 360x640 7.0ms
# Speed: 56.7ms track, 7.0ms solution per image at shape (1, 3, 360, 640)
#
# 360: 360x640 14.8ms
# Speed: 67.1ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 361: 360x640 4.9ms
# Speed: 60.9ms track, 4.9ms solution per image at shape (1, 3, 360, 640)
#
# 362: 360x640 9.4ms
# Speed: 70.7ms track, 9.4ms solution per image at shape (1, 3, 360, 640)
#
# 363: 360x640 16.3ms
# Speed: 64.7ms track, 16.3ms solution per image at shape (1, 3, 360, 640)
#
# 364: 360x640 14.3ms
# Speed: 67.3ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 365: 360x640 10.7ms
# Speed: 53.2ms track, 10.7ms solution per image at shape (1, 3, 360, 640)
#
# 366: 360x640 18.0ms
# Speed: 63.6ms track, 18.0ms solution per image at shape (1, 3, 360, 640)
#
# 367: 360x640 14.5ms
# Speed: 67.3ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 368: 360x640 3.8ms
# Speed: 60.4ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 369: 360x640 4.4ms
# Speed: 61.8ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 370: 360x640 14.6ms
# Speed: 66.2ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 371: 360x640 11.7ms
# Speed: 68.7ms track, 11.7ms solution per image at shape (1, 3, 360, 640)
#
# 372: 360x640 16.9ms
# Speed: 65.2ms track, 16.9ms solution per image at shape (1, 3, 360, 640)
#
# 373: 360x640 17.4ms
# Speed: 63.5ms track, 17.4ms solution per image at shape (1, 3, 360, 640)
#
# 374: 360x640 4.7ms
# Speed: 58.9ms track, 4.7ms solution per image at shape (1, 3, 360, 640)
#
# 375: 360x640 8.0ms
# Speed: 56.9ms track, 8.0ms solution per image at shape (1, 3, 360, 640)
#
# 376: 360x640 17.1ms
# Speed: 64.0ms track, 17.1ms solution per image at shape (1, 3, 360, 640)
#
# 377: 360x640 11.4ms
# Speed: 53.4ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 378: 360x640 8.7ms
# Speed: 56.1ms track, 8.7ms solution per image at shape (1, 3, 360, 640)
#
# 379: 360x640 8.0ms
# Speed: 57.4ms track, 8.0ms solution per image at shape (1, 3, 360, 640)
#
# 380: 360x640 17.0ms
# Speed: 63.9ms track, 17.0ms solution per image at shape (1, 3, 360, 640)
#
# 381: 360x640 14.7ms
# Speed: 67.5ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 382: 360x640 11.6ms
# Speed: 55.3ms track, 11.6ms solution per image at shape (1, 3, 360, 640)
#
# 383: 360x640 4.6ms
# Speed: 58.9ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 384: 360x640 15.6ms
# Speed: 65.2ms track, 15.6ms solution per image at shape (1, 3, 360, 640)
#
# 385: 360x640 14.6ms
# Speed: 66.0ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 386: 360x640 6.2ms
# Speed: 58.0ms track, 6.2ms solution per image at shape (1, 3, 360, 640)
#
# 387: 360x640 4.8ms
# Speed: 61.7ms track, 4.8ms solution per image at shape (1, 3, 360, 640)
#
# 388: 360x640 12.0ms
# Speed: 67.9ms track, 12.0ms solution per image at shape (1, 3, 360, 640)
#
# 389: 360x640 10.4ms
# Speed: 85.7ms track, 10.4ms solution per image at shape (1, 3, 360, 640)
#
# 390: 360x640 11.4ms
# Speed: 54.1ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 391: 360x640 16.5ms
# Speed: 48.3ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 392: 360x640 11.8ms
# Speed: 51.6ms track, 11.8ms solution per image at shape (1, 3, 360, 640)
#
# 393: 360x640 13.5ms
# Speed: 50.5ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 394: 360x640 3.6ms
# Speed: 48.0ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 395: 360x640 13.6ms
# Speed: 48.9ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 396: 360x640 7.9ms
# Speed: 56.0ms track, 7.9ms solution per image at shape (1, 3, 360, 640)
#
# 397: 360x640 2.9ms
# Speed: 60.4ms track, 2.9ms solution per image at shape (1, 3, 360, 640)
#
# 398: 360x640 16.6ms
# Speed: 48.2ms track, 16.6ms solution per image at shape (1, 3, 360, 640)
#
# 399: 360x640 10.2ms
# Speed: 53.9ms track, 10.2ms solution per image at shape (1, 3, 360, 640)
#
# 400: 360x640 3.2ms
# Speed: 45.9ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 401: 360x640 8.4ms
# Speed: 55.1ms track, 8.4ms solution per image at shape (1, 3, 360, 640)
#
# 402: 360x640 4.6ms
# Speed: 59.9ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 403: 360x640 4.4ms
# Speed: 60.5ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 404: 360x640 5.9ms
# Speed: 58.9ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 405: 360x640 4.3ms
# Speed: 61.8ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 406: 360x640 3.2ms
# Speed: 44.2ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 407: 360x640 14.6ms
# Speed: 49.6ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 408: 360x640 7.4ms
# Speed: 56.5ms track, 7.4ms solution per image at shape (1, 3, 360, 640)
#
# 409: 360x640 8.6ms
# Speed: 56.5ms track, 8.6ms solution per image at shape (1, 3, 360, 640)
#
# 410: 360x640 9.7ms
# Speed: 55.5ms track, 9.7ms solution per image at shape (1, 3, 360, 640)
#
# 411: 360x640 14.5ms
# Speed: 66.3ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 412: 360x640 8.9ms
# Speed: 54.9ms track, 8.9ms solution per image at shape (1, 3, 360, 640)
#
# 413: 360x640 3.6ms
# Speed: 61.1ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 414: 360x640 14.0ms
# Speed: 49.3ms track, 14.0ms solution per image at shape (1, 3, 360, 640)
#
# 415: 360x640 15.4ms
# Speed: 66.2ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 416: 360x640 14.7ms
# Speed: 66.8ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 417: 360x640 4.3ms
# Speed: 62.6ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 418: 360x640 16.1ms
# Speed: 46.5ms track, 16.1ms solution per image at shape (1, 3, 360, 640)
#
# 419: 360x640 14.8ms
# Speed: 49.7ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 420: 360x640 3.7ms
# Speed: 61.3ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 421: 360x640 9.9ms
# Speed: 54.1ms track, 9.9ms solution per image at shape (1, 3, 360, 640)
#
# 422: 360x640 8.0ms
# Speed: 56.7ms track, 8.0ms solution per image at shape (1, 3, 360, 640)
#
# 423: 360x640 14.8ms
# Speed: 66.3ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 424: 360x640 14.1ms
# Speed: 67.2ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 425: 360x640 14.0ms
# Speed: 67.5ms track, 14.0ms solution per image at shape (1, 3, 360, 640)
#
# 426: 360x640 14.4ms
# Speed: 67.0ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 427: 360x640 14.7ms
# Speed: 50.1ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 428: 360x640 16.5ms
# Speed: 63.9ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 429: 360x640 3.5ms
# Speed: 61.8ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 430: 360x640 17.7ms
# Speed: 47.2ms track, 17.7ms solution per image at shape (1, 3, 360, 640)
#
# 431: 360x640 3.4ms
# Speed: 61.1ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 432: 360x640 5.7ms
# Speed: 59.3ms track, 5.7ms solution per image at shape (1, 3, 360, 640)
#
# 433: 360x640 8.7ms
# Speed: 56.3ms track, 8.7ms solution per image at shape (1, 3, 360, 640)
#
# 434: 360x640 6.4ms
# Speed: 57.8ms track, 6.4ms solution per image at shape (1, 3, 360, 640)
#
# 435: 360x640 15.6ms
# Speed: 65.1ms track, 15.6ms solution per image at shape (1, 3, 360, 640)
#
# 436: 360x640 17.5ms
# Speed: 63.5ms track, 17.5ms solution per image at shape (1, 3, 360, 640)
#
# 437: 360x640 4.5ms
# Speed: 59.4ms track, 4.5ms solution per image at shape (1, 3, 360, 640)
#
# 438: 360x640 6.3ms
# Speed: 58.0ms track, 6.3ms solution per image at shape (1, 3, 360, 640)
#
# 439: 360x640 10.7ms
# Speed: 53.4ms track, 10.7ms solution per image at shape (1, 3, 360, 640)
#
# 440: 360x640 2.3ms
# Speed: 65.3ms track, 2.3ms solution per image at shape (1, 3, 360, 640)
#
# 441: 360x640 9.8ms
# Speed: 68.6ms track, 9.8ms solution per image at shape (1, 3, 360, 640)
#
# 442: 360x640 8.4ms
# Speed: 56.8ms track, 8.4ms solution per image at shape (1, 3, 360, 640)
#
# 443: 360x640 17.8ms
# Speed: 63.4ms track, 17.8ms solution per image at shape (1, 3, 360, 640)
#
# 444: 360x640 17.2ms
# Speed: 64.7ms track, 17.2ms solution per image at shape (1, 3, 360, 640)
#
# 445: 360x640 15.4ms
# Speed: 65.2ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 446: 360x640 16.3ms
# Speed: 64.3ms track, 16.3ms solution per image at shape (1, 3, 360, 640)
#
# 447: 360x640 18.9ms
# Speed: 78.4ms track, 18.9ms solution per image at shape (1, 3, 360, 640)
#
# 448: 360x640 12.6ms
# Speed: 51.3ms track, 12.6ms solution per image at shape (1, 3, 360, 640)
#
# 449: 360x640 8.9ms
# Speed: 56.2ms track, 8.9ms solution per image at shape (1, 3, 360, 640)
#
# 450: 360x640 12.2ms
# Speed: 53.0ms track, 12.2ms solution per image at shape (1, 3, 360, 640)
#
# 451: 360x640 3.2ms
# Speed: 47.0ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 452: 360x640 2.8ms
# Speed: 60.4ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 453: 360x640 14.7ms
# Speed: 65.6ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 454: 360x640 6.0ms
# Speed: 58.4ms track, 6.0ms solution per image at shape (1, 3, 360, 640)
#
# 455: 360x640 2.2ms
# Speed: 47.0ms track, 2.2ms solution per image at shape (1, 3, 360, 640)
#
# 456: 360x640 8.1ms
# Speed: 55.3ms track, 8.1ms solution per image at shape (1, 3, 360, 640)
#
# 457: 360x640 18.0ms
# Speed: 63.6ms track, 18.0ms solution per image at shape (1, 3, 360, 640)
#
# 458: 360x640 11.6ms
# Speed: 52.9ms track, 11.6ms solution per image at shape (1, 3, 360, 640)
#
# 459: 360x640 7.2ms
# Speed: 57.6ms track, 7.2ms solution per image at shape (1, 3, 360, 640)
#
# 460: 360x640 9.2ms
# Speed: 55.6ms track, 9.2ms solution per image at shape (1, 3, 360, 640)
#
# 461: 360x640 3.5ms
# Speed: 62.8ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 462: 360x640 18.2ms
# Speed: 61.9ms track, 18.2ms solution per image at shape (1, 3, 360, 640)
#
# 463: 360x640 3.7ms
# Speed: 63.8ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 464: 360x640 16.6ms
# Speed: 62.2ms track, 16.6ms solution per image at shape (1, 3, 360, 640)
#
# 465: 360x640 15.5ms
# Speed: 65.9ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 466: 360x640 3.4ms
# Speed: 64.5ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 467: 360x640 17.3ms
# Speed: 60.2ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 468: 360x640 9.5ms
# Speed: 55.5ms track, 9.5ms solution per image at shape (1, 3, 360, 640)
#
# 469: 360x640 15.0ms
# Speed: 49.3ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 470: 360x640 17.0ms
# Speed: 65.2ms track, 17.0ms solution per image at shape (1, 3, 360, 640)
#
# 471: 360x640 11.8ms
# Speed: 68.2ms track, 11.8ms solution per image at shape (1, 3, 360, 640)
#
# 472: 360x640 7.0ms
# Speed: 57.1ms track, 7.0ms solution per image at shape (1, 3, 360, 640)
#
# 473: 360x640 16.9ms
# Speed: 62.8ms track, 16.9ms solution per image at shape (1, 3, 360, 640)
#
# 474: 360x640 3.5ms
# Speed: 63.5ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 475: 360x640 3.5ms
# Speed: 59.4ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 476: 360x640 3.6ms
# Speed: 61.1ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 477: 360x640 16.9ms
# Speed: 64.4ms track, 16.9ms solution per image at shape (1, 3, 360, 640)
#
# 478: 360x640 8.3ms
# Speed: 54.9ms track, 8.3ms solution per image at shape (1, 3, 360, 640)
#
# 479: 360x640 3.5ms
# Speed: 61.1ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 480: 360x640 3.4ms
# Speed: 62.8ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 481: 360x640 18.2ms
# Speed: 62.3ms track, 18.2ms solution per image at shape (1, 3, 360, 640)
#
# 482: 360x640 16.1ms
# Speed: 65.6ms track, 16.1ms solution per image at shape (1, 3, 360, 640)
#
# 483: 360x640 2.8ms
# Speed: 60.9ms track, 2.8ms solution per image at shape (1, 3, 360, 640)
#
# 484: 360x640 14.3ms
# Speed: 67.3ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 485: 360x640 14.0ms
# Speed: 51.5ms track, 14.0ms solution per image at shape (1, 3, 360, 640)
#
# 486: 360x640 7.3ms
# Speed: 56.8ms track, 7.3ms solution per image at shape (1, 3, 360, 640)
#
# 487: 360x640 8.2ms
# Speed: 56.7ms track, 8.2ms solution per image at shape (1, 3, 360, 640)
#
# 488: 360x640 6.6ms
# Speed: 57.6ms track, 6.6ms solution per image at shape (1, 3, 360, 640)
#
# 489: 360x640 8.8ms
# Speed: 55.1ms track, 8.8ms solution per image at shape (1, 3, 360, 640)
#
# 490: 360x640 6.3ms
# Speed: 57.9ms track, 6.3ms solution per image at shape (1, 3, 360, 640)
#
# 491: 360x640 9.3ms
# Speed: 55.7ms track, 9.3ms solution per image at shape (1, 3, 360, 640)
#
# 492: 360x640 6.4ms
# Speed: 57.0ms track, 6.4ms solution per image at shape (1, 3, 360, 640)
#
# 493: 360x640 11.9ms
# Speed: 52.9ms track, 11.9ms solution per image at shape (1, 3, 360, 640)
#
# 494: 360x640 6.4ms
# Speed: 59.7ms track, 6.4ms solution per image at shape (1, 3, 360, 640)
#
# 495: 360x640 5.6ms
# Speed: 73.5ms track, 5.6ms solution per image at shape (1, 3, 360, 640)
#
# 496: 360x640 11.9ms
# Speed: 70.2ms track, 11.9ms solution per image at shape (1, 3, 360, 640)
#
# 497: 360x640 15.5ms
# Speed: 65.0ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 498: 360x640 10.9ms
# Speed: 53.9ms track, 10.9ms solution per image at shape (1, 3, 360, 640)
#
# 499: 360x640 9.6ms
# Speed: 54.7ms track, 9.6ms solution per image at shape (1, 3, 360, 640)
#
# 500: 360x640 5.8ms
# Speed: 59.1ms track, 5.8ms solution per image at shape (1, 3, 360, 640)
#
# 501: 360x640 10.4ms
# Speed: 54.3ms track, 10.4ms solution per image at shape (1, 3, 360, 640)
#
# 502: 360x640 3.8ms
# Speed: 60.2ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 503: 360x640 14.6ms
# Speed: 65.5ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 504: 360x640 7.7ms
# Speed: 56.5ms track, 7.7ms solution per image at shape (1, 3, 360, 640)
#
# 505: 360x640 16.9ms
# Speed: 64.0ms track, 16.9ms solution per image at shape (1, 3, 360, 640)
#
# 506: 360x640 15.4ms
# Speed: 66.1ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 507: 360x640 5.2ms
# Speed: 59.1ms track, 5.2ms solution per image at shape (1, 3, 360, 640)
#
# 508: 360x640 9.9ms
# Speed: 54.3ms track, 9.9ms solution per image at shape (1, 3, 360, 640)
#
# 509: 360x640 17.0ms
# Speed: 64.7ms track, 17.0ms solution per image at shape (1, 3, 360, 640)
#
# 510: 360x640 16.7ms
# ...
#
# 1333: 360x640 13.1ms
# Speed: 48.6ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 1334: 360x640 16.9ms
# Speed: 44.7ms track, 16.9ms solution per image at shape (1, 3, 360, 640)
#
# 1335: 360x640 11.4ms
# Speed: 50.5ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 1336: 360x640 13.3ms
# Speed: 48.0ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 1337: 360x640 11.4ms
# Speed: 49.7ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 1338: 360x640 13.5ms
# Speed: 48.1ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 1339: 360x640 14.4ms
# Speed: 47.2ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 1340: 360x640 10.3ms
# Speed: 51.2ms track, 10.3ms solution per image at shape (1, 3, 360, 640)
#
# 1341: 360x640 16.2ms
# Speed: 45.0ms track, 16.2ms solution per image at shape (1, 3, 360, 640)
#
# 1342: 360x640 9.9ms
# Speed: 52.1ms track, 9.9ms solution per image at shape (1, 3, 360, 640)
#
# 1343: 360x640 12.0ms
# Speed: 48.6ms track, 12.0ms solution per image at shape (1, 3, 360, 640)
#
# 1344: 360x640 10.8ms
# Speed: 51.0ms track, 10.8ms solution per image at shape (1, 3, 360, 640)
#
# 1345: 360x640 4.4ms
# Speed: 56.3ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 1346: 360x640 13.2ms
# Speed: 48.1ms track, 13.2ms solution per image at shape (1, 3, 360, 640)
#
# 1347: 360x640 7.7ms
# Speed: 53.7ms track, 7.7ms solution per image at shape (1, 3, 360, 640)
#
# 1348: 360x640 15.7ms
# Speed: 46.1ms track, 15.7ms solution per image at shape (1, 3, 360, 640)
#
# 1349: 360x640 12.0ms
# Speed: 49.6ms track, 12.0ms solution per image at shape (1, 3, 360, 640)
#
# 1350: 360x640 10.0ms
# Speed: 51.4ms track, 10.0ms solution per image at shape (1, 3, 360, 640)
#
# 1351: 360x640 9.1ms
# Speed: 52.3ms track, 9.1ms solution per image at shape (1, 3, 360, 640)
#
# 1352: 360x640 13.4ms
# Speed: 48.9ms track, 13.4ms solution per image at shape (1, 3, 360, 640)
#
# 1353: 360x640 14.6ms
# Speed: 46.6ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 1354: 360x640 13.8ms
# Speed: 47.7ms track, 13.8ms solution per image at shape (1, 3, 360, 640)
#
# 1355: 360x640 8.2ms
# Speed: 53.6ms track, 8.2ms solution per image at shape (1, 3, 360, 640)
#
# 1356: 360x640 12.6ms
# Speed: 48.8ms track, 12.6ms solution per image at shape (1, 3, 360, 640)
#
# 1357: 360x640 7.4ms
# Speed: 54.0ms track, 7.4ms solution per image at shape (1, 3, 360, 640)
#
# 1358: 360x640 11.4ms
# Speed: 49.6ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 1359: 360x640 12.7ms
# Speed: 48.6ms track, 12.7ms solution per image at shape (1, 3, 360, 640)
#
# 1360: 360x640 13.7ms
# Speed: 47.3ms track, 13.7ms solution per image at shape (1, 3, 360, 640)
#
# 1361: 360x640 12.5ms
# Speed: 49.1ms track, 12.5ms solution per image at shape (1, 3, 360, 640)
#
# 1362: 360x640 15.5ms
# Speed: 46.2ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 1363: 360x640 10.5ms
# Speed: 51.4ms track, 10.5ms solution per image at shape (1, 3, 360, 640)
#
# 1364: 360x640 15.0ms
# Speed: 46.6ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 1365: 360x640 13.3ms
# Speed: 48.6ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 1366: 360x640 12.0ms
# Speed: 49.0ms track, 12.0ms solution per image at shape (1, 3, 360, 640)
#
# 1367: 360x640 13.6ms
# Speed: 48.3ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 1368: 360x640 12.4ms
# Speed: 49.8ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 1369: 360x640 16.3ms
# Speed: 45.4ms track, 16.3ms solution per image at shape (1, 3, 360, 640)
#
# 1370: 360x640 3.5ms
# Speed: 57.9ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 1371: 360x640 15.3ms
# Speed: 46.1ms track, 15.3ms solution per image at shape (1, 3, 360, 640)
#
# 1372: 360x640 14.1ms
# Speed: 47.7ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 1373: 360x640 15.8ms
# Speed: 45.3ms track, 15.8ms solution per image at shape (1, 3, 360, 640)
#
# 1374: 360x640 10.9ms
# Speed: 50.7ms track, 10.9ms solution per image at shape (1, 3, 360, 640)
#
# 1375: 360x640 15.4ms
# Speed: 46.8ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 1376: 360x640 14.5ms
# Speed: 47.0ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 1377: 360x640 15.2ms
# Speed: 46.6ms track, 15.2ms solution per image at shape (1, 3, 360, 640)
#
# 1378: 360x640 1.9ms
# Speed: 43.8ms track, 1.9ms solution per image at shape (1, 3, 360, 640)
#
# 1379: 360x640 16.5ms
# Speed: 45.3ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 1380: 360x640 5.5ms
# Speed: 40.2ms track, 5.5ms solution per image at shape (1, 3, 360, 640)
#
# 1381: 360x640 2.5ms
# Speed: 43.1ms track, 2.5ms solution per image at shape (1, 3, 360, 640)
#
# 1382: 360x640 12.7ms
# Speed: 49.0ms track, 12.7ms solution per image at shape (1, 3, 360, 640)
#
# 1383: 360x640 17.5ms
# Speed: 44.3ms track, 17.5ms solution per image at shape (1, 3, 360, 640)
#
# 1384: 360x640 3.0ms
# Speed: 42.7ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 1385: 360x640 13.3ms
# Speed: 48.5ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 1386: 360x640 15.1ms
# Speed: 46.7ms track, 15.1ms solution per image at shape (1, 3, 360, 640)
#
# 1387: 360x640 16.6ms
# Speed: 44.6ms track, 16.6ms solution per image at shape (1, 3, 360, 640)
#
# 1388: 360x640 10.1ms
# Speed: 50.3ms track, 10.1ms solution per image at shape (1, 3, 360, 640)
#
# 1389: 360x640 13.1ms
# Speed: 48.5ms track, 13.1ms solution per image at shape (1, 3, 360, 640)
#
# 1390: 360x640 11.9ms
# Speed: 50.0ms track, 11.9ms solution per image at shape (1, 3, 360, 640)
#
# 1391: 360x640 14.2ms
# Speed: 48.2ms track, 14.2ms solution per image at shape (1, 3, 360, 640)
#
# 1392: 360x640 16.8ms
# Speed: 44.5ms track, 16.8ms solution per image at shape (1, 3, 360, 640)
#
# 1393: 360x640 10.7ms
# Speed: 50.3ms track, 10.7ms solution per image at shape (1, 3, 360, 640)
#
# 1394: 360x640 8.8ms
# Speed: 52.7ms track, 8.8ms solution per image at shape (1, 3, 360, 640)
#
# 1395: 360x640 13.7ms
# Speed: 47.8ms track, 13.7ms solution per image at shape (1, 3, 360, 640)
#
# 1396: 360x640 15.5ms
# Speed: 46.6ms track, 15.5ms solution per image at shape (1, 3, 360, 640)
#
# 1397: 360x640 15.4ms
# Speed: 46.4ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 1398: 360x640 12.1ms
# Speed: 49.9ms track, 12.1ms solution per image at shape (1, 3, 360, 640)
#
# 1399: 360x640 12.7ms
# Speed: 49.3ms track, 12.7ms solution per image at shape (1, 3, 360, 640)
#
# 1400: 360x640 16.4ms
# Speed: 45.2ms track, 16.4ms solution per image at shape (1, 3, 360, 640)
#
# 1401: 360x640 14.2ms
# Speed: 47.4ms track, 14.2ms solution per image at shape (1, 3, 360, 640)
#
# 1402: 360x640 14.8ms
# Speed: 46.5ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 1403: 360x640 15.6ms
# Speed: 45.9ms track, 15.6ms solution per image at shape (1, 3, 360, 640)
#
# 1404: 360x640 3.0ms
# Speed: 58.3ms track, 3.0ms solution per image at shape (1, 3, 360, 640)
#
# 1405: 360x640 17.5ms
# Speed: 43.7ms track, 17.5ms solution per image at shape (1, 3, 360, 640)
#
# 1406: 360x640 12.8ms
# Speed: 49.2ms track, 12.8ms solution per image at shape (1, 3, 360, 640)
#
# 1407: 360x640 17.3ms
# Speed: 44.2ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 1408: 360x640 16.5ms
# Speed: 44.6ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 1409: 360x640 10.0ms
# Speed: 51.7ms track, 10.0ms solution per image at shape (1, 3, 360, 640)
#
# 1410: 360x640 17.3ms
# Speed: 44.5ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 1411: 360x640 12.3ms
# Speed: 49.3ms track, 12.3ms solution per image at shape (1, 3, 360, 640)
#
# 1412: 360x640 16.1ms
# Speed: 45.0ms track, 16.1ms solution per image at shape (1, 3, 360, 640)
#
# 1413: 360x640 15.8ms
# Speed: 45.6ms track, 15.8ms solution per image at shape (1, 3, 360, 640)
#
# 1414: 360x640 14.3ms
# Speed: 47.3ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 1415: 360x640 15.7ms
# Speed: 46.4ms track, 15.7ms solution per image at shape (1, 3, 360, 640)
#
# 1416: 360x640 15.2ms
# Speed: 45.8ms track, 15.2ms solution per image at shape (1, 3, 360, 640)
#
# 1417: 360x640 12.0ms
# Speed: 49.3ms track, 12.0ms solution per image at shape (1, 3, 360, 640)
#
# 1418: 360x640 14.9ms
# Speed: 46.6ms track, 14.9ms solution per image at shape (1, 3, 360, 640)
#
# 1419: 360x640 15.2ms
# Speed: 46.4ms track, 15.2ms solution per image at shape (1, 3, 360, 640)
#
# 1420: 360x640 14.6ms
# Speed: 45.7ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 1421: 360x640 11.7ms
# Speed: 49.9ms track, 11.7ms solution per image at shape (1, 3, 360, 640)
#
# 1422: 360x640 13.2ms
# Speed: 47.6ms track, 13.2ms solution per image at shape (1, 3, 360, 640)
#
# 1423: 360x640 12.4ms
# Speed: 49.5ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 1424: 360x640 11.8ms
# Speed: 49.8ms track, 11.8ms solution per image at shape (1, 3, 360, 640)
#
# 1425: 360x640 14.3ms
# Speed: 47.5ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 1426: 360x640 15.0ms
# Speed: 46.3ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 1427: 360x640 12.5ms
# Speed: 49.2ms track, 12.5ms solution per image at shape (1, 3, 360, 640)
#
# 1428: 360x640 14.1ms
# Speed: 48.0ms track, 14.1ms solution per image at shape (1, 3, 360, 640)
#
# 1429: 360x640 11.4ms
# Speed: 50.3ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 1430: 360x640 9.5ms
# Speed: 52.6ms track, 9.5ms solution per image at shape (1, 3, 360, 640)
#
# 1431: 360x640 13.3ms
# Speed: 48.3ms track, 13.3ms solution per image at shape (1, 3, 360, 640)
#
# 1432: 360x640 12.4ms
# Speed: 49.3ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 1433: 360x640 14.9ms
# Speed: 46.6ms track, 14.9ms solution per image at shape (1, 3, 360, 640)
#
# 1434: 360x640 17.4ms
# Speed: 44.2ms track, 17.4ms solution per image at shape (1, 3, 360, 640)
#
# 1435: 360x640 6.2ms
# Speed: 55.1ms track, 6.2ms solution per image at shape (1, 3, 360, 640)
#
# 1436: 360x640 6.9ms
# Speed: 55.0ms track, 6.9ms solution per image at shape (1, 3, 360, 640)
#
# 1437: 360x640 5.6ms
# Speed: 55.6ms track, 5.6ms solution per image at shape (1, 3, 360, 640)
#
# 1438: 360x640 6.8ms
# Speed: 55.4ms track, 6.8ms solution per image at shape (1, 3, 360, 640)
#
# 1439: 360x640 6.8ms
# Speed: 54.1ms track, 6.8ms solution per image at shape (1, 3, 360, 640)
#
# 1440: 360x640 13.5ms
# Speed: 48.0ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 1441: 360x640 17.6ms
# Speed: 43.5ms track, 17.6ms solution per image at shape (1, 3, 360, 640)
#
# 1442: 360x640 12.1ms
# Speed: 49.1ms track, 12.1ms solution per image at shape (1, 3, 360, 640)
#
# 1443: 360x640 13.6ms
# Speed: 47.8ms track, 13.6ms solution per image at shape (1, 3, 360, 640)
#
# 1444: 360x640 16.5ms
# Speed: 44.9ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 1445: 360x640 14.5ms
# Speed: 46.9ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 1446: 360x640 16.7ms
# Speed: 45.1ms track, 16.7ms solution per image at shape (1, 3, 360, 640)
#
# 1447: 360x640 14.7ms
# Speed: 46.7ms track, 14.7ms solution per image at shape (1, 3, 360, 640)
#
# 1448: 360x640 11.5ms
# Speed: 50.2ms track, 11.5ms solution per image at shape (1, 3, 360, 640)
#
# 1449: 360x640 13.5ms
# Speed: 48.4ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 1450: 360x640 17.4ms
# Speed: 44.7ms track, 17.4ms solution per image at shape (1, 3, 360, 640)
#
# 1451: 360x640 9.6ms
# Speed: 52.4ms track, 9.6ms solution per image at shape (1, 3, 360, 640)
#
# 1452: 360x640 14.5ms
# Speed: 46.7ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 1453: 360x640 12.1ms
# Speed: 48.9ms track, 12.1ms solution per image at shape (1, 3, 360, 640)
#
# 1454: 360x640 16.0ms
# Speed: 45.5ms track, 16.0ms solution per image at shape (1, 3, 360, 640)
#
# 1455: 360x640 14.9ms
# Speed: 47.5ms track, 14.9ms solution per image at shape (1, 3, 360, 640)
#
# 1456: 360x640 14.6ms
# Speed: 46.4ms track, 14.6ms solution per image at shape (1, 3, 360, 640)
#
# 1457: 360x640 17.1ms
# Speed: 44.3ms track, 17.1ms solution per image at shape (1, 3, 360, 640)
#
# 1458: 360x640 14.3ms
# Speed: 47.0ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 1459: 360x640 16.8ms
# Speed: 44.9ms track, 16.8ms solution per image at shape (1, 3, 360, 640)
#
# 1460: 360x640 14.8ms
# Speed: 46.6ms track, 14.8ms solution per image at shape (1, 3, 360, 640)
#
# 1461: 360x640 12.0ms
# Speed: 49.7ms track, 12.0ms solution per image at shape (1, 3, 360, 640)
#
# 1462: 360x640 15.2ms
# Speed: 46.4ms track, 15.2ms solution per image at shape (1, 3, 360, 640)
#
# 1463: 360x640 17.3ms
# Speed: 43.8ms track, 17.3ms solution per image at shape (1, 3, 360, 640)
#
# 1464: 360x640 14.5ms
# Speed: 46.6ms track, 14.5ms solution per image at shape (1, 3, 360, 640)
#
# 1465: 360x640 11.4ms
# Speed: 49.5ms track, 11.4ms solution per image at shape (1, 3, 360, 640)
#
# 1466: 360x640 16.0ms
# Speed: 45.3ms track, 16.0ms solution per image at shape (1, 3, 360, 640)
#
# 1467: 360x640 17.9ms
# Speed: 43.8ms track, 17.9ms solution per image at shape (1, 3, 360, 640)
#
# 1468: 360x640 14.4ms
# Speed: 46.7ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 1469: 360x640 12.9ms
# Speed: 49.2ms track, 12.9ms solution per image at shape (1, 3, 360, 640)
#
# 1470: 360x640 14.4ms
# Speed: 46.8ms track, 14.4ms solution per image at shape (1, 3, 360, 640)
#
# 1471: 360x640 12.6ms
# Speed: 49.5ms track, 12.6ms solution per image at shape (1, 3, 360, 640)
#
# 1472: 360x640 12.4ms
# Speed: 49.0ms track, 12.4ms solution per image at shape (1, 3, 360, 640)
#
# 1473: 360x640 3.9ms
# Speed: 41.4ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 1474: 360x640 15.0ms
# Speed: 46.6ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 1475: 360x640 13.2ms
# Speed: 48.0ms track, 13.2ms solution per image at shape (1, 3, 360, 640)
#
# 1476: 360x640 11.5ms
# Speed: 50.4ms track, 11.5ms solution per image at shape (1, 3, 360, 640)
#
# 1477: 360x640 12.3ms
# Speed: 48.8ms track, 12.3ms solution per image at shape (1, 3, 360, 640)
#
# 1478: 360x640 15.0ms
# Speed: 46.7ms track, 15.0ms solution per image at shape (1, 3, 360, 640)
#
# 1479: 360x640 16.8ms
# Speed: 45.3ms track, 16.8ms solution per image at shape (1, 3, 360, 640)
#
# 1480: 360x640 15.1ms
# Speed: 46.3ms track, 15.1ms solution per image at shape (1, 3, 360, 640)
#
# 1481: 360x640 17.0ms
# Speed: 44.6ms track, 17.0ms solution per image at shape (1, 3, 360, 640)
#
# 1482: 360x640 15.4ms
# Speed: 46.2ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 1483: 360x640 12.2ms
# Speed: 49.3ms track, 12.2ms solution per image at shape (1, 3, 360, 640)
#
# 1484: 360x640 2.6ms
# Speed: 43.1ms track, 2.6ms solution per image at shape (1, 3, 360, 640)
#
# 1485: 360x640 13.0ms
# Speed: 48.3ms track, 13.0ms solution per image at shape (1, 3, 360, 640)
#
# 1486: 360x640 15.4ms
# Speed: 46.7ms track, 15.4ms solution per image at shape (1, 3, 360, 640)
#
# 1487: 360x640 15.3ms
# Speed: 46.3ms track, 15.3ms solution per image at shape (1, 3, 360, 640)
#
# 1488: 360x640 15.7ms
# Speed: 45.8ms track, 15.7ms solution per image at shape (1, 3, 360, 640)
#
# 1489: 360x640 14.3ms
# Speed: 46.4ms track, 14.3ms solution per image at shape (1, 3, 360, 640)
#
# 1490: 360x640 12.6ms
# Speed: 48.6ms track, 12.6ms solution per image at shape (1, 3, 360, 640)
#
# 1491: 360x640 15.7ms
# Speed: 46.1ms track, 15.7ms solution per image at shape (1, 3, 360, 640)
#
# 1492: 360x640 13.4ms
# Speed: 47.2ms track, 13.4ms solution per image at shape (1, 3, 360, 640)
#
# 1493: 360x640 16.5ms
# Speed: 46.9ms track, 16.5ms solution per image at shape (1, 3, 360, 640)
#
# 1494: 360x640 11.0ms
# Speed: 50.1ms track, 11.0ms solution per image at shape (1, 3, 360, 640)
#
# 1495: 360x640 15.8ms
# Speed: 45.9ms track, 15.8ms solution per image at shape (1, 3, 360, 640)
#
# 1496: 360x640 11.6ms
# Speed: 49.3ms track, 11.6ms solution per image at shape (1, 3, 360, 640)
#
# 1497: 360x640 14.9ms
# Speed: 46.4ms track, 14.9ms solution per image at shape (1, 3, 360, 640)
#
# 1498: 360x640 13.5ms
# Speed: 48.4ms track, 13.5ms solution per image at shape (1, 3, 360, 640)
#
# 1499: 360x640 11.7ms
# Speed: 49.3ms track, 11.7ms solution per image at shape (1, 3, 360, 640)
#
# 1500: 360x640 8.7ms
# Speed: 53.2ms track, 8.7ms solution per image at shape (1, 3, 360, 640)
#
# Video frame is empty or processing is complete.
